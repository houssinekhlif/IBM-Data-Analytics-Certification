# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Removing Duplicates**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you will focus on data wrangling, an important step in preparing data for analysis. Data wrangling involves cleaning and organizing data to make it suitable for analysis. One key task in this process is removing duplicate entries, which are repeated entries that can distort analysis and lead to inaccurate conclusions.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# 1. Identify duplicate rows  in the dataset.
# 2. Use suitable techniques to remove duplicate rows and verify the removal.
# 3. Summarize how to handle missing values appropriately.
# 4. Use ConvertedCompYearly to normalize compensation data.

# %% [markdown]
# ### Install the Required Libraries

# %%
# !pip install pandas

# %% [markdown]
# ### Step 1: Import Required Libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2: Load the Dataset into a DataFrame

# %% [markdown]
# #### **Read Data**

# %% [markdown]
# If you are using JupyterLite, use the code below to download the dataset into your environment. If you are using a local environment, you can use the direct URL with <code>pd.read_csv()</code>.

# %%
from pyodide.http import pyfetch

async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())

# Define the file path for the data
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv"

# Download the dataset
await download(file_path, "survey_data.csv")
file_name = "survey_data.csv"

# %% [markdown]
# **Load the data into a pandas dataframe:**

# %%
file_name=r"C:\Users\21650\Downloads\survey_data.csv"
df = pd.read_csv(file_name)

# %% [markdown]
# **Note: If you are working on a local Jupyter environment, you can use the URL directly in the <code>pandas.read_csv()</code>  function as shown below:**

# %% [markdown]
# ##### df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv")

# %% [markdown]
# ### Step 3: Identifying Duplicate Rows

# %% [markdown]
# **Task 1: Identify Duplicate Rows**
#   1. Count the number of duplicate rows in the dataset.
#   2. Display the first few duplicate rows to understand their structure.

# %%
cols = ["MainBranch", "Employment", "RemoteWork","Country", "YearsCode", "DevType","CompTotal","WorkExp","EdLevel"]
df[cols].value_counts().reset_index(name="count").head(10)
# Out:
#                        MainBranch           Employment  \
# 0  I am a developer by profession  Employed, full-time
# 1  I am a developer by profession  Employed, full-time
# 2  I am a developer by profession  Employed, full-time
# 3  I am a developer by profession  Employed, full-time
# 4  I am a developer by profession  Employed, full-time
# 5  I am a developer by profession  Employed, full-time
# 6  I am a developer by profession  Employed, full-time
# 7  I am a developer by profession  Employed, full-time
# 8  I am a developer by profession  Employed, full-time
# 9  I am a developer by profession  Employed, full-time
#
#                              RemoteWork  \
# 0                                Remote
# 1                             In-person
# 2                             In-person
# 3  Hybrid (some remote, some in-person)
# 4  Hybrid (some remote, some in-person)
# 5  Hybrid (some remote, some in-person)
# 6  Hybrid (some remote, some in-person)
# 7  Hybrid (some remote, some in-person)
# 8  Hybrid (some remote, some in-person)
# 9  Hybrid (some remote, some in-person)
#
#                                              Country YearsCode  \
# 0                           United States of America        12
# 1                                              India         4
# 2                                              India         2
# 3                                             Poland         9
# 4                                             Canada        12
# 5                                        Philippines         6
# 6                           United States of America        14
# 7                                              India        15
# 8                                             Canada         8
# 9  United Kingdom of Great Britain and Northern I...         5
#
#                  DevType  CompTotal  WorkExp  \
# 0  Developer, full-stack   110000.0      7.0
# 1  Developer, full-stack   500000.0      1.0
# 2  Developer, full-stack   483000.0      2.0
# 3  Developer, full-stack   250000.0     17.0
# 4    Developer, back-end    90000.0      6.0
# 5      DevOps specialist   300000.0      2.0
# 6    Developer, back-end   200000.0     10.0
# 7      Developer, mobile  3500000.0     11.0
# 8  Developer, full-stack    80000.0      4.0
# 9  Developer, full-stack    30000.0      1.0
#
#                                            EdLevel  count
# 0     Bachelor’s degree (B.A., B.S., B.Eng., etc.)      3
# 1     Bachelor’s degree (B.A., B.S., B.Eng., etc.)      2
# 2     Bachelor’s degree (B.A., B.S., B.Eng., etc.)      2
# 3  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)      2
# 4     Bachelor’s degree (B.A., B.S., B.Eng., etc.)      2
# 5     Bachelor’s degree (B.A., B.S., B.Eng., etc.)      2
# 6     Bachelor’s degree (B.A., B.S., B.Eng., etc.)      2
# 7     Bachelor’s degree (B.A., B.S., B.Eng., etc.)      2
# 8     Bachelor’s degree (B.A., B.S., B.Eng., etc.)      2
# 9     Bachelor’s degree (B.A., B.S., B.Eng., etc.)      2

# %%
# your code goes here
cols = ["MainBranch", "Employment", "RemoteWork","Country", "YearsCode", "DevType","CompTotal","WorkExp","EdLevel"]
dup_rows=df[df.duplicated(subset=cols)]
print(f"There are {len(dup_rows)} duplicate rows.")
dup_rows.head()
# Out:
# There are 7240 duplicate rows.
#       ResponseId                      MainBranch                 Age  \
# 366          367  I am a developer by profession     35-44 years old
# 911          912  I am a developer by profession     45-54 years old
# 970          971     I code primarily as a hobby     18-24 years old
# 1072        1073  I am a developer by profession     55-64 years old
# 1428        1429           I am learning to code  Under 18 years old
#
#                                              Employment RemoteWork   Check  \
# 366                                 Employed, full-time     Remote  Apples
# 911   Independent contractor, freelancer, or self-em...  In-person  Apples
# 970                                  Student, full-time        NaN  Apples
# 1072  Independent contractor, freelancer, or self-em...     Remote  Apples
# 1428                                 Student, full-time        NaN  Apples
#
#                                        CodingActivities  \
# 366   Hobby;Professional development or self-paced l...
# 911   Hobby;Contribute to open-source projects;Profe...
# 970                                                 NaN
# 1072  Professional development or self-paced learnin...
# 1428                                                NaN
#
#                                                 EdLevel  \
# 366        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 911   Secondary school (e.g. American high school, G...
# 970   Secondary school (e.g. American high school, G...
# 1072    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1428  Secondary school (e.g. American high school, G...
#
#                                               LearnCode  \
# 366                     Online Courses or Certification
# 911   Books / Physical media;Colleague;Other online ...
# 970   Other online resources (e.g., videos, blogs, f...
# 1072  Books / Physical media;On the job training;Oth...
# 1428  Other online resources (e.g., videos, blogs, f...
#
#                                         LearnCodeOnline  ... JobSatPoints_6  \
# 366                                                 NaN  ...           60.0
# 911   Technical documentation;Blogs;Books;Written Tu...  ...            NaN
# 970   Technical documentation;Blogs;Books;Written Tu...  ...            NaN
# 1072  Technical documentation;Books;Written Tutorial...  ...            NaN
# 1428  Books;Stack Overflow;How-to videos;Video-based...  ...            NaN
#
#      JobSatPoints_7 JobSatPoints_8 JobSatPoints_9 JobSatPoints_10  \
# 366            30.0           10.0            0.0             0.0
# 911             NaN            NaN            NaN             NaN
# 970             NaN            NaN            NaN             NaN
# 1072            NaN            NaN            NaN             NaN
# 1428            NaN            NaN            NaN             NaN
#
#      JobSatPoints_11           SurveyLength SurveyEase ConvertedCompYearly  \
# 366              0.0  Appropriate in length       Easy                 NaN
# 911              NaN  Appropriate in length       Easy             76307.0
# 970              NaN  Appropriate in length       Easy                 NaN
# 1072             NaN  Appropriate in length       Easy                 NaN
# 1428             NaN  Appropriate in length       Easy                 NaN
#
#      JobSat
# 366     5.0
# 911     NaN
# 970     NaN
# 1072    NaN
# 1428    NaN
#
# [5 rows x 114 columns]

# %% [markdown]
# ### Step 4: Removing Duplicate Rows

# %% [markdown]
# **Task 2: Remove Duplicates**
#    1. Remove duplicate rows from the dataset using the drop_duplicates() function.
# 2. Verify the removal by counting the number of duplicate rows after removal .

# %%
# your code goes here
a=len(df)
df.drop_duplicates(subset=cols,inplace=True)
b=len(df)
print("Number of duplicate rows removed:", a-b)
# Out:
# Number of duplicate rows removed: 7240

# %% [markdown]
# ### Step 5: Handling Missing Values

# %% [markdown]
# **Task 3: Identify and Handle Missing Values**
#    1. Identify missing values for all columns in the dataset.
#    2. Choose a column with significant missing values (e.g., EdLevel) and impute with the most frequent value.

# %%
# your code goes here
for col in df.columns.values.tolist():
    print(f"column: {col}\nmissing values: {df[col].isna().sum()}\n\n")
# Out:
# column: ResponseId
# missing values: 0
#
#
# column: MainBranch
# missing values: 0
#
#
# column: Age
# missing values: 0
#
#
# column: Employment
# missing values: 0
#
#
# column: RemoteWork
# missing values: 8052
#
#
# column: Check
# missing values: 0
#
#
# column: CodingActivities
# missing values: 8058
#
#
# column: EdLevel
# missing values: 256
#
#
# column: LearnCode
# missing values: 477
#
#
# column: LearnCodeOnline
# missing values: 11163
#
#
# column: TechDoc
# missing values: 18876
#
#
# column: YearsCode
# missing values: 792
#
#
# column: YearsCodePro
# missing values: 7882
#
#
# column: DevType
# missing values: 1188
#
#
# column: OrgSize
# missing values: 11569
#
#
# column: PurchaseInfluence
# missing values: 11632
#
#
# column: BuyNewTool
# missing values: 13775
#
#
# column: BuildvsBuy
# missing values: 15496
#
#
# column: TechEndorse
# missing values: 15149
#
#
# column: Country
# missing values: 1508
#
#
# column: Currency
# missing values: 12171
#
#
# column: CompTotal
# missing values: 24561
#
#
# column: LanguageHaveWorkedWith
# missing values: 2271
#
#
# column: LanguageWantToWorkWith
# missing values: 5922
#
#
# column: LanguageAdmired
# missing values: 10321
#
#
# column: DatabaseHaveWorkedWith
# missing values: 10813
#
#
# column: DatabaseWantToWorkWith
# missing values: 17940
#
#
# column: DatabaseAdmired
# missing values: 21604
#
#
# column: PlatformHaveWorkedWith
# missing values: 18106
#
#
# column: PlatformWantToWorkWith
# missing values: 25473
#
#
# column: PlatformAdmired
# missing values: 28384
#
#
# column: WebframeHaveWorkedWith
# missing values: 15575
#
#
# column: WebframeWantToWorkWith
# missing values: 21731
#
#
# column: WebframeAdmired
# missing values: 25069
#
#
# column: EmbeddedHaveWorkedWith
# missing values: 37389
#
#
# column: EmbeddedWantToWorkWith
# missing values: 41671
#
#
# column: EmbeddedAdmired
# missing values: 42466
#
#
# column: MiscTechHaveWorkedWith
# missing values: 20753
#
#
# column: MiscTechWantToWorkWith
# missing values: 26858
#
#
# column: MiscTechAdmired
# missing values: 30046
#
#
# column: ToolsTechHaveWorkedWith
# missing values: 8290
#
#
# column: ToolsTechWantToWorkWith
# missing values: 14292
#
#
# column: ToolsTechAdmired
# missing values: 16252
#
#
# column: NEWCollabToolsHaveWorkedWith
# missing values: 3425
#
#
# column: NEWCollabToolsWantToWorkWith
# missing values: 8598
#
#
# column: NEWCollabToolsAdmired
# missing values: 9874
#
#
# column: OpSysPersonal use
# missing values: 2885
#
#
# column: OpSysProfessional use
# missing values: 7522
#
#
# column: OfficeStackAsyncHaveWorkedWith
# missing values: 11965
#
#
# column: OfficeStackAsyncWantToWorkWith
# missing values: 20670
#
#
# column: OfficeStackAsyncAdmired
# missing values: 22362
#
#
# column: OfficeStackSyncHaveWorkedWith
# missing values: 5050
#
#
# column: OfficeStackSyncWantToWorkWith
# missing values: 13450
#
#
# column: OfficeStackSyncAdmired
# missing values: 15366
#
#
# column: AISearchDevHaveWorkedWith
# missing values: 15767
#
#
# column: AISearchDevWantToWorkWith
# missing values: 23155
#
#
# column: AISearchDevAdmired
# missing values: 24265
#
#
# column: NEWSOSites
# missing values: 1604
#
#
# column: SOVisitFreq
# missing values: 2244
#
#
# column: SOAccount
# missing values: 2221
#
#
# column: SOPartFreq
# missing values: 15315
#
#
# column: SOHow
# missing values: 2594
#
#
# column: SOComm
# missing values: 2374
#
#
# column: AISelect
# missing values: 1521
#
#
# column: AISent
# missing values: 15764
#
#
# column: AIBen
# missing values: 24108
#
#
# column: AIAcc
# missing values: 23688
#
#
# column: AIComplex
# missing values: 23905
#
#
# column: AIToolCurrently Using
# missing values: 25360
#
#
# column: AIToolInterested in Using
# missing values: 29409
#
#
# column: AIToolNot interested in Using
# missing values: 35262
#
#
# column: AINextMuch more integrated
# missing values: 45533
#
#
# column: AINextNo change
# missing values: 46377
#
#
# column: AINextMore integrated
# missing values: 35118
#
#
# column: AINextLess integrated
# missing values: 56057
#
#
# column: AINextMuch less integrated
# missing values: 57141
#
#
# column: AIThreat
# missing values: 16053
#
#
# column: AIEthics
# missing values: 18747
#
#
# column: AIChallenges
# missing values: 22264
#
#
# column: TBranch
# missing values: 14277
#
#
# column: ICorPM
# missing values: 28592
#
#
# column: WorkExp
# missing values: 28732
#
#
# column: Knowledge_1
# missing values: 29695
#
#
# column: Knowledge_2
# missing values: 30332
#
#
# column: Knowledge_3
# missing values: 30260
#
#
# column: Knowledge_4
# missing values: 30323
#
#
# column: Knowledge_5
# missing values: 30472
#
#
# column: Knowledge_6
# missing values: 30486
#
#
# column: Knowledge_7
# missing values: 30570
#
#
# column: Knowledge_8
# missing values: 30591
#
#
# column: Knowledge_9
# missing values: 30711
#
#
# column: Frequency_1
# missing values: 29994
#
#
# column: Frequency_2
# missing values: 30001
#
#
# column: Frequency_3
# missing values: 30648
#
#
# column: TimeSearching
# missing values: 29466
#
#
# column: TimeAnswering
# missing values: 29531
#
#
# column: Frustration
# missing values: 30116
#
#
# column: ProfessionalTech
# missing values: 30590
#
#
# column: ProfessionalCloud
# missing values: 29881
#
#
# column: ProfessionalQuestion
# missing values: 29569
#
#
# column: Industry
# missing values: 29519
#
#
# column: JobSatPoints_1
# missing values: 29061
#
#
# column: JobSatPoints_4
# missing values: 28992
#
#
# column: JobSatPoints_5
# missing values: 28974
#
#
# column: JobSatPoints_6
# missing values: 28935
#
#
# column: JobSatPoints_7
# missing values: 28937
#
#
# column: JobSatPoints_8
# missing values: 28930
#
#
# column: JobSatPoints_9
# missing values: 28930
#
#
# column: JobSatPoints_10
# missing values: 28936
#
#
# column: JobSatPoints_11
# missing values: 28941
#
#
# column: SurveyLength
# missing values: 4051
#
#
# column: SurveyEase
# missing values: 3993
#
#
# column: ConvertedCompYearly
# missing values: 34810
#
#
# column: JobSat
# missing values: 29255

# %%
mode=df["EdLevel"].value_counts().idxmax()
df["EdLevel"].fillna(mode,inplace=True)
print(df["EdLevel"].isna().sum())
# Out:
# np.int64(0)

# %% [markdown]
# ### Step 6: Normalizing Compensation Data

# %% [markdown]
# **Task 4: Normalize Compensation Data Using ConvertedCompYearly**
#    1. Use the ConvertedCompYearly column for compensation analysis as the normalized annual compensation is already provided.
#    2. Check for missing values in ConvertedCompYearly and handle them if necessary.

# %%
# your code goes here

# %%
df["ConvertedCompYearly"].describe()
# Out:
# count    2.338700e+04
# mean     8.613105e+04
# std      1.869297e+05
# min      1.000000e+00
# 25%      3.269600e+04
# 50%      6.500000e+04
# 75%      1.079370e+05
# max      1.625660e+07
# Name: ConvertedCompYearly, dtype: float64

# %%
print("missing values:",df["ConvertedCompYearly"].isna().sum())
# Out:
# missing values: 34810

# %%
df["ConvertedCompYearly"].fillna(df["ConvertedCompYearly"].median(),inplace=True)

# %% [markdown]
# ### Step 7: Summary and Next Steps

# %% [markdown]
# **In this lab, you focused on identifying and removing duplicate rows.**
#
# - You handled missing values by imputing the most frequent value in a chosen column.
#
# - You used ConvertedCompYearly for compensation normalization and handled missing values.
#
# - For further analysis, consider exploring other columns or visualizing the cleaned dataset.

# %% [markdown]
# <!--
# ## Change Log
#
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-11-05|1.2|Madhusudhan Moole|Updated lab|
# |2024-09-24|1.1|Madhusudhan Moole|Updated lab|
# |2024-09-23|1.0|Raghul Ramesh|Created lab|
#
# --!>

# %% [markdown]
# ## <h3 align="center"> © IBM Corporation. All rights reserved. <h3/>
