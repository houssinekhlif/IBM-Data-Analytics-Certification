# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Data Wrangling Lab**

# %% [markdown]
# Estimated time needed: **45** minutes

# %% [markdown]
# In this lab, you will perform data wrangling tasks to prepare raw data for analysis. Data wrangling involves cleaning, transforming, and organizing data into a structured format suitable for analysis. This lab focuses on tasks like identifying inconsistencies, encoding categorical variables, and feature transformation.

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab, you will be able to:

# %% [markdown]
# - Identify and remove inconsistent data entries.
#
# - Encode categorical variables for analysis.
#
# - Handle missing values using multiple imputation strategies.
#
# - Apply feature scaling and transformation techniques.

# %% [markdown]
# #### Intsall the required libraries

# %%
# !pip install pandas
# !pip install matplotlib

# %% [markdown]
# ## Tasks

# %% [markdown]
# #### Step 1: Import the necessary module.

# %% [markdown]
# ### 1. Load the Dataset

# %% [markdown]
# <h5>1.1 Import necessary libraries and load the dataset.</h5>

# %% [markdown]
# Ensure the dataset is loaded correctly by displaying the first few rows.

# %%
# Import necessary libraries
import pandas as pd

# Load the Stack Overflow survey data
dataset_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv"
df = pd.read_csv(dataset_url)

# Display the first few rows
print(df.head())

# %%
# Import necessary libraries
import pandas as pd

# Load the Stack Overflow survey data
dataset_url = r"C:\Users\21650\Downloads\survey_data.csv"
df = pd.read_csv(dataset_url)

# Display the first few rows
print(df.head())
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# 4                                                NaN
#
#                                              EdLevel  \
# 0                          Primary/elementary school
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3  Some college/university study without earning ...
# 4  Secondary school (e.g. American high school, G...
#
#                                            LearnCode  \
# 0                             Books / Physical media
# 1  Books / Physical media;Colleague;On the job tr...
# 2  Books / Physical media;Colleague;On the job tr...
# 3  Other online resources (e.g., videos, blogs, f...
# 4  Other online resources (e.g., videos, blogs, f...
#
#                                      LearnCodeOnline  ... JobSatPoints_6  \
# 0                                                NaN  ...            NaN
# 1  Technical documentation;Blogs;Books;Written Tu...  ...            0.0
# 2  Technical documentation;Blogs;Books;Written Tu...  ...            NaN
# 3  Stack Overflow;How-to videos;Interactive tutorial  ...            NaN
# 4  Technical documentation;Blogs;Written Tutorial...  ...            NaN
#
#   JobSatPoints_7 JobSatPoints_8 JobSatPoints_9 JobSatPoints_10  \
# 0            NaN            NaN            NaN             NaN
# 1            0.0            0.0            0.0             0.0
# 2            NaN            NaN            NaN             NaN
# 3            NaN            NaN            NaN             NaN
# 4            NaN            NaN            NaN             NaN
#
#   JobSatPoints_11           SurveyLength SurveyEase ConvertedCompYearly JobSat
# 0             NaN                    NaN        NaN                 NaN    NaN
# 1             0.0                    NaN        NaN                 NaN    NaN
# 2             NaN  Appropriate in length       Easy                 NaN    NaN
# 3             NaN               Too long       Easy                 NaN    NaN
# 4             NaN              Too short       Easy                 NaN    NaN
#
# [5 rows x 114 columns]

# %% [markdown]
# #### 2. Explore the Dataset

# %% [markdown]
# <h5>2.1 Summarize the dataset by displaying the column data types, counts, and missing values.</h5>

# %%
# Write your code here
for col in df.columns.values.tolist():
    print(f"column name:{col}\ncolumn data type:{df[col].dtype}\ncounts:{df[col].notnull().sum()}\nmissing values:{df[col].isna().sum()}\n\n")
# Out:
# column name:ResponseId
# column data type:int64
# counts:65437
# missing values:0
#
#
# column name:MainBranch
# column data type:object
# counts:65437
# missing values:0
#
#
# column name:Age
# column data type:object
# counts:65437
# missing values:0
#
#
# column name:Employment
# column data type:object
# counts:65437
# missing values:0
#
#
# column name:RemoteWork
# column data type:object
# counts:54806
# missing values:10631
#
#
# column name:Check
# column data type:object
# counts:65437
# missing values:0
#
#
# column name:CodingActivities
# column data type:object
# counts:54466
# missing values:10971
#
#
# column name:EdLevel
# column data type:object
# counts:60784
# missing values:4653
#
#
# column name:LearnCode
# column data type:object
# counts:60488
# missing values:4949
#
#
# column name:LearnCodeOnline
# column data type:object
# counts:49237
# missing values:16200
#
#
# column name:TechDoc
# column data type:object
# counts:40897
# missing values:24540
#
#
# column name:YearsCode
# column data type:object
# counts:59869
# missing values:5568
#
#
# column name:YearsCodePro
# column data type:object
# counts:51610
# missing values:13827
#
#
# column name:DevType
# column data type:object
# counts:59445
# missing values:5992
#
#
# column name:OrgSize
# column data type:object
# counts:47480
# missing values:17957
#
#
# column name:PurchaseInfluence
# column data type:object
# counts:47406
# missing values:18031
#
#
# column name:BuyNewTool
# column data type:object
# counts:45181
# missing values:20256
#
#
# column name:BuildvsBuy
# column data type:object
# counts:43358
# missing values:22079
#
#
# column name:TechEndorse
# column data type:object
# counts:43668
# missing values:21769
#
#
# column name:Country
# column data type:object
# counts:58930
# missing values:6507
#
#
# column name:Currency
# column data type:object
# counts:46684
# missing values:18753
#
#
# column name:CompTotal
# column data type:float64
# counts:33740
# missing values:31697
#
#
# column name:LanguageHaveWorkedWith
# column data type:object
# counts:59745
# missing values:5692
#
#
# column name:LanguageWantToWorkWith
# column data type:object
# counts:55752
# missing values:9685
#
#
# column name:LanguageAdmired
# column data type:object
# counts:50872
# missing values:14565
#
#
# column name:DatabaseHaveWorkedWith
# column data type:object
# counts:50254
# missing values:15183
#
#
# column name:DatabaseWantToWorkWith
# column data type:object
# counts:42558
# missing values:22879
#
#
# column name:DatabaseAdmired
# column data type:object
# counts:38557
# missing values:26880
#
#
# column name:PlatformHaveWorkedWith
# column data type:object
# counts:42366
# missing values:23071
#
#
# column name:PlatformWantToWorkWith
# column data type:object
# counts:34532
# missing values:30905
#
#
# column name:PlatformAdmired
# column data type:object
# counts:31377
# missing values:34060
#
#
# column name:WebframeHaveWorkedWith
# column data type:object
# counts:45161
# missing values:20276
#
#
# column name:WebframeWantToWorkWith
# column data type:object
# counts:38535
# missing values:26902
#
#
# column name:WebframeAdmired
# column data type:object
# counts:34943
# missing values:30494
#
#
# column name:EmbeddedHaveWorkedWith
# column data type:object
# counts:22214
# missing values:43223
#
#
# column name:EmbeddedWantToWorkWith
# column data type:object
# counts:17600
# missing values:47837
#
#
# column name:EmbeddedAdmired
# column data type:object
# counts:16733
# missing values:48704
#
#
# column name:MiscTechHaveWorkedWith
# column data type:object
# counts:39443
# missing values:25994
#
#
# column name:MiscTechWantToWorkWith
# column data type:object
# counts:32964
# missing values:32473
#
#
# column name:MiscTechAdmired
# column data type:object
# counts:29596
# missing values:35841
#
#
# column name:ToolsTechHaveWorkedWith
# column data type:object
# counts:52482
# missing values:12955
#
#
# column name:ToolsTechWantToWorkWith
# column data type:object
# counts:46084
# missing values:19353
#
#
# column name:ToolsTechAdmired
# column data type:object
# counts:43997
# missing values:21440
#
#
# column name:NEWCollabToolsHaveWorkedWith
# column data type:object
# counts:57592
# missing values:7845
#
#
# column name:NEWCollabToolsWantToWorkWith
# column data type:object
# counts:52087
# missing values:13350
#
#
# column name:NEWCollabToolsAdmired
# column data type:object
# counts:50711
# missing values:14726
#
#
# column name:OpSysPersonal use
# column data type:object
# counts:58174
# missing values:7263
#
#
# column name:OpSysProfessional use
# column data type:object
# counts:52973
# missing values:12464
#
#
# column name:OfficeStackAsyncHaveWorkedWith
# column data type:object
# counts:48093
# missing values:17344
#
#
# column name:OfficeStackAsyncWantToWorkWith
# column data type:object
# counts:38966
# missing values:26471
#
#
# column name:OfficeStackAsyncAdmired
# column data type:object
# counts:37204
# missing values:28233
#
#
# column name:OfficeStackSyncHaveWorkedWith
# column data type:object
# counts:55545
# missing values:9892
#
#
# column name:OfficeStackSyncWantToWorkWith
# column data type:object
# counts:46711
# missing values:18726
#
#
# column name:OfficeStackSyncAdmired
# column data type:object
# counts:44712
# missing values:20725
#
#
# column name:AISearchDevHaveWorkedWith
# column data type:object
# counts:44453
# missing values:20984
#
#
# column name:AISearchDevWantToWorkWith
# column data type:object
# counts:36701
# missing values:28736
#
#
# column name:AISearchDevAdmired
# column data type:object
# counts:35543
# missing values:29894
#
#
# column name:NEWSOSites
# column data type:object
# counts:60286
# missing values:5151
#
#
# column name:SOVisitFreq
# column data type:object
# counts:59536
# missing values:5901
#
#
# column name:SOAccount
# column data type:object
# counts:59560
# missing values:5877
#
#
# column name:SOPartFreq
# column data type:object
# counts:45237
# missing values:20200
#
#
# column name:SOHow
# column data type:object
# counts:58962
# missing values:6475
#
#
# column name:SOComm
# column data type:object
# counts:59163
# missing values:6274
#
#
# column name:AISelect
# column data type:object
# counts:60907
# missing values:4530
#
#
# column name:AISent
# column data type:object
# counts:45873
# missing values:19564
#
#
# column name:AIBen
# column data type:object
# counts:36894
# missing values:28543
#
#
# column name:AIAcc
# column data type:object
# counts:37302
# missing values:28135
#
#
# column name:AIComplex
# column data type:object
# counts:37021
# missing values:28416
#
#
# column name:AIToolCurrently Using
# column data type:object
# counts:35072
# missing values:30365
#
#
# column name:AIToolInterested in Using
# column data type:object
# counts:30691
# missing values:34746
#
#
# column name:AIToolNot interested in Using
# column data type:object
# counts:24414
# missing values:41023
#
#
# column name:AINextMuch more integrated
# column data type:object
# counts:13438
# missing values:51999
#
#
# column name:AINextNo change
# column data type:object
# counts:12498
# missing values:52939
#
#
# column name:AINextMore integrated
# column data type:object
# counts:24428
# missing values:41009
#
#
# column name:AINextLess integrated
# column data type:object
# counts:2355
# missing values:63082
#
#
# column name:AINextMuch less integrated
# column data type:object
# counts:1148
# missing values:64289
#
#
# column name:AIThreat
# column data type:object
# counts:44689
# missing values:20748
#
#
# column name:AIEthics
# column data type:object
# counts:41548
# missing values:23889
#
#
# column name:AIChallenges
# column data type:object
# counts:37531
# missing values:27906
#
#
# column name:TBranch
# column data type:object
# counts:44477
# missing values:20960
#
#
# column name:ICorPM
# column data type:object
# counts:29801
# missing values:35636
#
#
# column name:WorkExp
# column data type:float64
# counts:29658
# missing values:35779
#
#
# column name:Knowledge_1
# column data type:object
# counts:28664
# missing values:36773
#
#
# column name:Knowledge_2
# column data type:object
# counts:28021
# missing values:37416
#
#
# column name:Knowledge_3
# column data type:object
# counts:28095
# missing values:37342
#
#
# column name:Knowledge_4
# column data type:object
# counts:28030
# missing values:37407
#
#
# column name:Knowledge_5
# column data type:object
# counts:27880
# missing values:37557
#
#
# column name:Knowledge_6
# column data type:object
# counts:27864
# missing values:37573
#
#
# column name:Knowledge_7
# column data type:object
# counts:27778
# missing values:37659
#
#
# column name:Knowledge_8
# column data type:object
# counts:27758
# missing values:37679
#
#
# column name:Knowledge_9
# column data type:object
# counts:27635
# missing values:37802
#
#
# column name:Frequency_1
# column data type:object
# counts:28369
# missing values:37068
#
#
# column name:Frequency_2
# column data type:object
# counts:28364
# missing values:37073
#
#
# column name:Frequency_3
# column data type:object
# counts:27710
# missing values:37727
#
#
# column name:TimeSearching
# column data type:object
# counts:28911
# missing values:36526
#
#
# column name:TimeAnswering
# column data type:object
# counts:28844
# missing values:36593
#
#
# column name:Frustration
# column data type:object
# counts:28251
# missing values:37186
#
#
# column name:ProfessionalTech
# column data type:object
# counts:27764
# missing values:37673
#
#
# column name:ProfessionalCloud
# column data type:object
# counts:28491
# missing values:36946
#
#
# column name:ProfessionalQuestion
# column data type:object
# counts:28807
# missing values:36630
#
#
# column name:Industry
# column data type:object
# counts:28858
# missing values:36579
#
#
# column name:JobSatPoints_1
# column data type:float64
# counts:29324
# missing values:36113
#
#
# column name:JobSatPoints_4
# column data type:float64
# counts:29393
# missing values:36044
#
#
# column name:JobSatPoints_5
# column data type:float64
# counts:29411
# missing values:36026
#
#
# column name:JobSatPoints_6
# column data type:float64
# counts:29450
# missing values:35987
#
#
# column name:JobSatPoints_7
# column data type:float64
# counts:29448
# missing values:35989
#
#
# column name:JobSatPoints_8
# column data type:float64
# counts:29456
# missing values:35981
#
#
# column name:JobSatPoints_9
# column data type:float64
# counts:29456
# missing values:35981
#
#
# column name:JobSatPoints_10
# column data type:float64
# counts:29450
# missing values:35987
#
#
# column name:JobSatPoints_11
# column data type:float64
# counts:29445
# missing values:35992
#
#
# column name:SurveyLength
# column data type:object
# counts:56182
# missing values:9255
#
#
# column name:SurveyEase
# column data type:object
# counts:56238
# missing values:9199
#
#
# column name:ConvertedCompYearly
# column data type:float64
# counts:23435
# missing values:42002
#
#
# column name:JobSat
# column data type:float64
# counts:29126
# missing values:36311

# %% [markdown]
# <h5>2.2 Generate basic statistics for numerical columns.</h5>

# %%
# Write your code here
df.describe()
# Out:
#          ResponseId      CompTotal       WorkExp  JobSatPoints_1  \
# count  65437.000000   3.374000e+04  29658.000000    29324.000000
# mean   32719.000000  2.963841e+145     11.466957       18.581094
# std    18890.179119  5.444117e+147      9.168709       25.966221
# min        1.000000   0.000000e+00      0.000000        0.000000
# 25%    16360.000000   6.000000e+04      4.000000        0.000000
# 50%    32719.000000   1.100000e+05      9.000000       10.000000
# 75%    49078.000000   2.500000e+05     16.000000       22.000000
# max    65437.000000  1.000000e+150     50.000000      100.000000
#
#        JobSatPoints_4  JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  \
# count    29393.000000    29411.000000    29450.000000     29448.00000
# mean         7.522140       10.060857       24.343232        22.96522
# std         18.422661       21.833836       27.089360        27.01774
# min          0.000000        0.000000        0.000000         0.00000
# 25%          0.000000        0.000000        0.000000         0.00000
# 50%          0.000000        0.000000       20.000000        15.00000
# 75%          5.000000       10.000000       30.000000        30.00000
# max        100.000000      100.000000      100.000000       100.00000
#
#        JobSatPoints_8  JobSatPoints_9  JobSatPoints_10  JobSatPoints_11  \
# count    29456.000000    29456.000000     29450.000000     29445.000000
# mean        20.278165       16.169432        10.955713         9.953948
# std         26.108110       24.845032        22.906263        21.775652
# min          0.000000        0.000000         0.000000         0.000000
# 25%          0.000000        0.000000         0.000000         0.000000
# 50%         10.000000        5.000000         0.000000         0.000000
# 75%         25.000000       20.000000        10.000000        10.000000
# max        100.000000      100.000000       100.000000       100.000000
#
#        ConvertedCompYearly        JobSat
# count         2.343500e+04  29126.000000
# mean          8.615529e+04      6.935041
# std           1.867570e+05      2.088259
# min           1.000000e+00      0.000000
# 25%           3.271200e+04      6.000000
# 50%           6.500000e+04      7.000000
# 75%           1.079715e+05      8.000000
# max           1.625660e+07     10.000000

# %% [markdown]
# ### 3. Identifying and Removing Inconsistencies

# %% [markdown]
# <h5>3.1 Identify inconsistent or irrelevant entries in specific columns (e.g., Country).</h5>

# %%
## Write your code here
for country in df["Country"].unique().tolist():
    print(country)
# Out:
# United States of America
# United Kingdom of Great Britain and Northern Ireland
# Canada
# Norway
# Uzbekistan
# Serbia
# Poland
# Philippines
# Bulgaria
# Switzerland
# India
# Germany
# Ireland
# Italy
# Ukraine
# Australia
# Brazil
# Japan
# Austria
# Iran, Islamic Republic of...
# France
# Saudi Arabia
# Romania
# Turkey
# Nepal
# Algeria
# Sweden
# Netherlands
# Croatia
# Pakistan
# Czech Republic
# Republic of North Macedonia
# Finland
# Slovakia
# Russian Federation
# Greece
# Israel
# Belgium
# Mexico
# United Republic of Tanzania
# Hungary
# Argentina
# Portugal
# Sri Lanka
# Latvia
# China
# Singapore
# Lebanon
# Spain
# South Africa
# Lithuania
# Viet Nam
# Dominican Republic
# Indonesia
# Kosovo
# Morocco
# Taiwan
# Georgia
# San Marino
# Tunisia
# Bangladesh
# Nigeria
# Liechtenstein
# Denmark
# Ecuador
# Malaysia
# Albania
# Azerbaijan
# Chile
# Ghana
# Peru
# Bolivia
# Egypt
# Luxembourg
# Montenegro
# Cyprus
# Paraguay
# Kazakhstan
# Slovenia
# Jordan
# Venezuela, Bolivarian Republic of...
# Costa Rica
# Jamaica
# Thailand
# Nicaragua
# Myanmar
# Republic of Korea
# Rwanda
# Bosnia and Herzegovina
# Benin
# El Salvador
# Zimbabwe
# Afghanistan
# Estonia
# Malta
# Uruguay
# Belarus
# Colombia
# Republic of Moldova
# Isle of Man
# Nomadic
# New Zealand
# Palestine
# Armenia
# United Arab Emirates
# Maldives
# Ethiopia
# Fiji
# Guatemala
# Uganda
# Turkmenistan
# Mauritius
# Kenya
# Cuba
# Gabon
# Bahamas
# South Korea
# Iceland
# Honduras
# Hong Kong (S.A.R.)
# Lao People's Democratic Republic
# Mongolia
# Cambodia
# Madagascar
# Angola
# Democratic Republic of the Congo
# Syrian Arab Republic
# Iraq
# Namibia
# Senegal
# Kyrgyzstan
# Zambia
# Swaziland
# Côte d'Ivoire
# Kuwait
# Tajikistan
# Burundi
# Trinidad and Tobago
# Mauritania
# Sierra Leone
# Panama
# Somalia
# North Korea
# Dominica
# Guyana
# Togo
# Oman
# Barbados
# Andorra
# Democratic People's Republic of Korea
# Qatar
# Sudan
# Cameroon
# Papua New Guinea
# Bahrain
# Yemen
# Malawi
# Burkina Faso
# Congo, Republic of the...
# Botswana
# Guinea-Bissau
# Mozambique
# Central African Republic
# Equatorial Guinea
# Suriname
# Belize
# Libyan Arab Jamahiriya
# Cape Verde
# Brunei Darussalam
# Bhutan
# Guinea
# Niger
# Antigua and Barbuda
# Mali
# Samoa
# Lesotho
# Saint Kitts and Nevis
# Monaco
# Micronesia, Federated States of...
# Haiti
# nan
# Nauru
# Liberia
# Chad
# Djibouti
# Solomon Islands

# %% [markdown]
# <h5>3.2 Standardize entries in columns like Country or EdLevel by mapping inconsistent values to a consistent format.</h5>

# %%
## Write your code here
countries_map={"United States of America":"United States",
               "United Kingdom of Great Britain and Northern Ireland":"United Kingdom",
               "Iran, Islamic Republic of...":"Iran",
               "Republic of North Macedonia":"North Macedonia",
               "Russian Federation":"Russia",
               "United Republic of Tanzania":"Tanzania",
               "Viet Nam":"Vietnam",
               "Venezuela, Bolivarian Republic of...":"Venezuela",
               "Republic of Korea":"South Korea",
               "Republic of Moldova":"Moldova",
               "Nomadic":None,
               "Hong Kong (S.A.R.)":"Hong Kong",
               "Lao People's Democratic Republic":"Laos",
               "Democratic Republic of the Congo":"Congo",
               "Syrian Arab Republic":"Syria",
               "Côte d'Ivoire":"Ivory Coast",
               "Democratic People's Republic of Korea":"North Korea",
               "Congo, Republic of the...":"Congo",
               "Libyan Arab Jamahiriya":"Libya",
               "Brunei Darussalam":"Brunei",
               "Micronesia, Federated States of...":"Micronesia"}

df["Country"]=df["Country"].replace(countries_map)

# %% [markdown]
# ### 4. Encoding Categorical Variables

# %% [markdown]
# <h5>4.1 Encode the Employment column using one-hot encoding.</h5>

# %%
## Write your code here
df_empl=pd.get_dummies(df["Employment"],prefix="Employment_")
df=pd.concat([df,df_empl],axis=1)

# %%
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# 4                                                NaN
#
#                                              EdLevel  \
# 0                          Primary/elementary school
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3  Some college/university study without earning ...
# 4  Secondary school (e.g. American high school, G...
#
#                                            LearnCode  \
# 0                             Books / Physical media
# 1  Books / Physical media;Colleague;On the job tr...
# 2  Books / Physical media;Colleague;On the job tr...
# 3  Other online resources (e.g., videos, blogs, f...
# 4  Other online resources (e.g., videos, blogs, f...
#
#                                      LearnCodeOnline  ...  \
# 0                                                NaN  ...
# 1  Technical documentation;Blogs;Books;Written Tu...  ...
# 2  Technical documentation;Blogs;Books;Written Tu...  ...
# 3  Stack Overflow;How-to videos;Interactive tutorial  ...
# 4  Technical documentation;Blogs;Written Tutorial...  ...
#
#   Employment__Student, full-time;Not employed, but looking for work;Not employed, and not looking for work;Student, part-time  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Employment__Student, full-time;Not employed, but looking for work;Retired  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Employment__Student, full-time;Not employed, but looking for work;Student, part-time  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Employment__Student, full-time;Retired  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#   Employment__Student, full-time;Student, part-time  \
# 0                                             False
# 1                                             False
# 2                                             False
# 3                                             False
# 4                                             False
#
#   Employment__Student, full-time;Student, part-time;Employed, part-time  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Employment__Student, full-time;Student, part-time;Retired  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Employment__Student, part-time  \
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
#
#   Employment__Student, part-time;Employed, part-time  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Employment__Student, part-time;Retired
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
# [5 rows x 224 columns]

# %% [markdown]
# ### 5. Handling Missing Values

# %% [markdown]
# <h5>5.1 Identify columns with the highest number of missing values.</h5>

# %%
## Write your code here
col_nan=df.isna().sum().reset_index()
col_nan.columns=["Column","Nan_Count"]
col_nan.sort_values(by="Nan_Count",ascending=False).head(10)
# Out:
#                             Column  Nan_Count
# 75      AINextMuch less integrated      64289
# 74           AINextLess integrated      63082
# 72                 AINextNo change      52939
# 71      AINextMuch more integrated      51999
# 36                 EmbeddedAdmired      48704
# 35          EmbeddedWantToWorkWith      47837
# 34          EmbeddedHaveWorkedWith      43223
# 112            ConvertedCompYearly      42002
# 70   AIToolNot interested in Using      41023
# 73           AINextMore integrated      41009

# %% [markdown]
# <h5>5.2 Impute missing values in numerical columns (e.g., `ConvertedCompYearly`) with the mean or median.</h5>

# %%
## Write your code here
for col in df.select_dtypes(include="number").columns.values.tolist():
    col_median=df[col].median()
    df[col].fillna(col_median,inplace=True)
# Out:
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\3218420124.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(col_median,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\3218420124.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(col_median,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\3218420124.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(col_median,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\3218420124.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(col_median,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\3218420124.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(col_median,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\3218420124.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(col_median,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\3218420124.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(col_median,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\3218420124.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(col_median,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\3218420124.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(col_median,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\3218420124.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(col_median,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\3218420124.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(col_median,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\3218420124.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(col_median,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\3218420124.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(col_median,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\3218420124.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(col_median,inplace=True)

# %% [markdown]
# <h5>5.3 Impute missing values in categorical columns (e.g., `RemoteWork`) with the most frequent value.</h5>

# %%
## Write your code here
for col in df.select_dtypes(include="object").columns.values.tolist():
    freq_entry=df[col].value_counts().idxmax()
    df[col].fillna(freq_entry,inplace=True)
# Out:
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)
# C:\Users\21650\AppData\Local\Temp\ipykernel_16564\660548156.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(freq_entry,inplace=True)

# %% [markdown]
# ### 6. Feature Scaling and Transformation

# %% [markdown]
# <h5>6.1 Apply Min-Max Scaling to normalize the `ConvertedCompYearly` column.</h5>

# %%
## Write your code here
df["ConvertedCompYearly"]=(df["ConvertedCompYearly"]-df["ConvertedCompYearly"].min())/(df["ConvertedCompYearly"].max()-df["ConvertedCompYearly"].min())

# %% [markdown]
# <h5>6.2 Log-transform the ConvertedCompYearly column to reduce skewness.</h5>

# %%
## Write your code here
import numpy as np
df["ConvertedCompYearly"]=np.log(df["ConvertedCompYearly"])
# Out:
# c:\Users\21650\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# ### 7. Feature Engineering

# %% [markdown]
# <h5>7.1 Create a new column `ExperienceLevel` based on the `YearsCodePro` column:</h5>

# %%
## Write your code here
years_map={'More than 50 years':'51','Less than 1 year':'0.5'}
df['YearsCodePro']=df['YearsCodePro'].replace(years_map)
df['YearsCodePro']=df['YearsCodePro'].astype('float')
categories=["low","medium","high"]
edges=np.linspace(df['YearsCodePro'].min(),df['YearsCodePro'].max(),4)
df["ExperienceLevel"]=pd.cut(df["YearsCodePro"],bins=edges,labels=categories,include_lowest=True)
df["ExperienceLevel"]
# Out:
# 0           low
# 1           low
# 2        medium
# 3           low
# 4           low
#           ...
# 65432       low
# 65433       low
# 65434       low
# 65435       low
# 65436       low
# Name: ExperienceLevel, Length: 65437, dtype: category
# Categories (3, object): ['low' < 'medium' < 'high']

# %% [markdown]
# ### Summary

# %% [markdown]
# In this lab, you:
#
# - Explored the dataset to identify inconsistencies and missing values.
#
# - Encoded categorical variables for analysis.
#
# - Handled missing values using imputation techniques.
#
# - Normalized and transformed numerical data to prepare it for analysis.
#
# - Engineered a new feature to enhance data interpretation.

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
